# %% [markdown]
# ### <center> Скромный Я

# %% [markdown]
# ### <center> Панды
# Больша́я па́нда, или бамбу́ковый медве́дь (лат. Ailuropoda melanoleuca) — вид всеядных млекопитающих из семейства медвежьих (Ursidae) со своеобразной чёрно-белой окраской шерсти, обладающих некоторыми признаками енотов. Единственный современный вид рода Ailuropus подсемейства Ailuropodinae. Большие панды обитают в горных регионах центрального Китая: Сычуань и Тибет.
# <center> <img src="external-content.duckduckgo.com.jpeg" width=1800>

# %% [markdown]
# ### <center> Pandas

# %%
import pandas as pd
df = pd.read_csv('raw_total_fight_data.csv', sep=';')
df.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.          ...           \
# 0           52%           47%    99 of 182    59 of 121          ...
# 1           72%           16%     37 of 40     42 of 52          ...
# 2           52%           36%   104 of 200    68 of 185          ...
# 3           38%           29%    76 of 195    58 of 192          ...
# 4           44%           59%    66 of 146    81 of 131          ...
#
#   B_GROUND                   win_by last_round last_round_time  \
# 0   1 of 1                   KO/TKO          3            4:51
# 1   0 of 0                   KO/TKO          2            0:26
# 2   0 of 0  TKO - Doctor's Stoppage          2            5:00
# 3  4 of 10     Decision - Unanimous          3            5:00
# 4   6 of 6     Decision - Unanimous          3            5:00
#
#               Format          Referee           date                location  \
# 0  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019  Chicago, Illinois, USA
# 1  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019  Chicago, Illinois, USA
# 2      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
# 3      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019  Chicago, Illinois, USA
# 4      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
#
#                          Fight_type                Winner
# 0       UFC Bantamweight Title Bout          Henry Cejudo
# 1  UFC Women's Flyweight Title Bout  Valentina Shevchenko
# 2                  Lightweight Bout         Tony Ferguson
# 3                 Bantamweight Bout              Petr Yan
# 4                  Heavyweight Bout         Blagoy Ivanov
#
# [5 rows x 41 columns]

# %% [markdown]
# #### Первичный анализ

# %%
df.head(5)
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.          ...           \
# 0           52%           47%    99 of 182    59 of 121          ...
# 1           72%           16%     37 of 40     42 of 52          ...
# 2           52%           36%   104 of 200    68 of 185          ...
# 3           38%           29%    76 of 195    58 of 192          ...
# 4           44%           59%    66 of 146    81 of 131          ...
#
#   B_GROUND                   win_by last_round last_round_time  \
# 0   1 of 1                   KO/TKO          3            4:51
# 1   0 of 0                   KO/TKO          2            0:26
# 2   0 of 0  TKO - Doctor's Stoppage          2            5:00
# 3  4 of 10     Decision - Unanimous          3            5:00
# 4   6 of 6     Decision - Unanimous          3            5:00
#
#               Format          Referee           date                location  \
# 0  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019  Chicago, Illinois, USA
# 1  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019  Chicago, Illinois, USA
# 2      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
# 3      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019  Chicago, Illinois, USA
# 4      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
#
#                          Fight_type                Winner
# 0       UFC Bantamweight Title Bout          Henry Cejudo
# 1  UFC Women's Flyweight Title Bout  Valentina Shevchenko
# 2                  Lightweight Bout         Tony Ferguson
# 3                 Bantamweight Bout              Petr Yan
# 4                  Heavyweight Bout         Blagoy Ivanov
#
# [5 rows x 41 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Data columns (total 41 columns):
# R_fighter          5144 non-null object
# B_fighter          5144 non-null object
# R_KD               5144 non-null int64
# B_KD               5144 non-null int64
# R_SIG_STR.         5144 non-null object
# B_SIG_STR.         5144 non-null object
# R_SIG_STR_pct      5144 non-null object
# B_SIG_STR_pct      5144 non-null object
# R_TOTAL_STR.       5144 non-null object
# B_TOTAL_STR.       5144 non-null object
# R_TD               5144 non-null object
# B_TD               5144 non-null object
# R_TD_pct           5144 non-null object
# B_TD_pct           5144 non-null object
# R_SUB_ATT          5144 non-null int64
# B_SUB_ATT          5144 non-null int64
# R_PASS             5144 non-null int64
# B_PASS             5144 non-null int64
# R_REV              5144 non-null int64
# B_REV              5144 non-null int64
# R_HEAD             5144 non-null object
# B_HEAD             5144 non-null object
# R_BODY             5144 non-null object
# B_BODY             5144 non-null object
# R_LEG              5144 non-null object
# B_LEG              5144 non-null object
# R_DISTANCE         5144 non-null object
# B_DISTANCE         5144 non-null object
# R_CLINCH           5144 non-null object
# B_CLINCH           5144 non-null object
# R_GROUND           5144 non-null object
# B_GROUND           5144 non-null object
# win_by             5144 non-null object
# last_round         5144 non-null int64
# last_round_time    5144 non-null object
# Format             5144 non-null object
# Referee            5121 non-null object
# date               5144 non-null object
# location           5144 non-null object
# Fight_type         5144 non-null object
# Winner             5061 non-null object
# dtypes: int64(9), object(32)
# memory usage: 10.7 MB

# %%
df.select_dtypes(include='object').head()
# Out:
#               R_fighter       B_fighter  R_SIG_STR. B_SIG_STR. R_SIG_STR_pct  \
# 0          Henry Cejudo   Marlon Moraes   90 of 171  57 of 119           52%
# 1  Valentina Shevchenko     Jessica Eye     8 of 11    2 of 12           72%
# 2         Tony Ferguson  Donald Cerrone  104 of 200  68 of 185           52%
# 3         Jimmie Rivera        Petr Yan   73 of 192  56 of 189           38%
# 4           Tai Tuivasa   Blagoy Ivanov   64 of 144  73 of 123           44%
#
#   B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#            ...           R_GROUND B_GROUND                   win_by  \
# 0          ...           26 of 30   1 of 1                   KO/TKO
# 1          ...             1 of 1   0 of 0                   KO/TKO
# 2          ...             0 of 0   0 of 0  TKO - Doctor's Stoppage
# 3          ...             4 of 4  4 of 10     Decision - Unanimous
# 4          ...             0 of 0   6 of 6     Decision - Unanimous
#
#   last_round_time             Format          Referee           date  \
# 0            4:51  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019
# 1            0:26  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019
# 2            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 3            5:00      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019
# 4            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
#
#                  location                        Fight_type  \
# 0  Chicago, Illinois, USA       UFC Bantamweight Title Bout
# 1  Chicago, Illinois, USA  UFC Women's Flyweight Title Bout
# 2  Chicago, Illinois, USA                  Lightweight Bout
# 3  Chicago, Illinois, USA                 Bantamweight Bout
# 4  Chicago, Illinois, USA                  Heavyweight Bout
#
#                  Winner
# 0          Henry Cejudo
# 1  Valentina Shevchenko
# 2         Tony Ferguson
# 3              Petr Yan
# 4         Blagoy Ivanov
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Работа с Strings

# %% [markdown]
# <center> <img src="external-content.ууу.com.jpeg" width=1800>

# %%
df['location'].head()
# Out:
# 0    Chicago, Illinois, USA
# 1    Chicago, Illinois, USA
# 2    Chicago, Illinois, USA
# 3    Chicago, Illinois, USA
# 4    Chicago, Illinois, USA
# Name: location, dtype: object

# %%
df['location'].str.split(',').head()
# Out:
# 0    [Chicago,  Illinois,  USA]
# 1    [Chicago,  Illinois,  USA]
# 2    [Chicago,  Illinois,  USA]
# 3    [Chicago,  Illinois,  USA]
# 4    [Chicago,  Illinois,  USA]
# Name: location, dtype: object

# %%
df['location'].str.split(',').str.len().value_counts()
# Out:
# 3    4694
# 2     450
# Name: location, dtype: int64

# %%
df['location'].str.split(',', expand=True).head()
# Out:
#          0          1     2
# 0  Chicago   Illinois   USA
# 1  Chicago   Illinois   USA
# 2  Chicago   Illinois   USA
# 3  Chicago   Illinois   USA
# 4  Chicago   Illinois   USA

# %%
pd.concat([df, df['location'].str.split(',', expand=True)], axis=1).head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ...  last_round_time  \
# 0           52%           47%    99 of 182    59 of 121  ...             4:51
# 1           72%           16%     37 of 40     42 of 52  ...             0:26
# 2           52%           36%   104 of 200    68 of 185  ...             5:00
# 3           38%           29%    76 of 195    58 of 192  ...             5:00
# 4           44%           59%    66 of 146    81 of 131  ...             5:00
#
#               Format          Referee           date                location  \
# 0  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019  Chicago, Illinois, USA
# 1  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019  Chicago, Illinois, USA
# 2      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
# 3      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019  Chicago, Illinois, USA
# 4      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019  Chicago, Illinois, USA
#
#                          Fight_type                Winner        0          1  \
# 0       UFC Bantamweight Title Bout          Henry Cejudo  Chicago   Illinois
# 1  UFC Women's Flyweight Title Bout  Valentina Shevchenko  Chicago   Illinois
# 2                  Lightweight Bout         Tony Ferguson  Chicago   Illinois
# 3                 Bantamweight Bout              Petr Yan  Chicago   Illinois
# 4                  Heavyweight Bout         Blagoy Ivanov  Chicago   Illinois
#
#       2
# 0   USA
# 1   USA
# 2   USA
# 3   USA
# 4   USA
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Конвертирование чисел

# %% [markdown]
# <center> <img src="laying_pandas.jpeg" width=1800>

# %%
df['R_SIG_STR_pct'].head()
# Out:
# 0    52%
# 1    72%
# 2    52%
# 3    38%
# 4    44%
# Name: R_SIG_STR_pct, dtype: object

# %%
df['R_SIG_STR_pct'].dtype
# Out:
# dtype('O')

# %%
df['R_SIG_STR_pct'].str.replace('%', '').head()
# Out:
# 0    52
# 1    72
# 2    52
# 3    38
# 4    44
# Name: R_SIG_STR_pct, dtype: object

# %%
pd.to_numeric(df['R_SIG_STR_pct'].str.replace('%', '')).head()
# Out:
# 0    52
# 1    72
# 2    52
# 3    38
# 4    44
# Name: R_SIG_STR_pct, dtype: int64

# %%
R_SIG_STR_pct = (pd.to_numeric(df['R_SIG_STR_pct'].str.replace('%', '')) / 100)
R_SIG_STR_pct.head()
# Out:
# 0    0.52
# 1    0.72
# 2    0.52
# 3    0.38
# 4    0.44
# Name: R_SIG_STR_pct, dtype: float64

# %% [markdown]
# ### Конвертирование дат

# %%
df['date'].head()
# Out:
# 0    June 08, 2019
# 1    June 08, 2019
# 2    June 08, 2019
# 3    June 08, 2019
# 4    June 08, 2019
# Name: date, dtype: object

# %%
date = pd.to_datetime(df['date'])
date.head()
# Out:
# 0   2019-06-08
# 1   2019-06-08
# 2   2019-06-08
# 3   2019-06-08
# 4   2019-06-08
# Name: date, dtype: datetime64[ns]

# %%
old_mem_usage = df['date'].memory_usage(deep='True')
new_mem_usage = date.memory_usage(deep='True')
print('Прежнее потребление памяти: ', old_mem_usage)
print('После конвертации ', new_mem_usage)
print(f'Улучшение в потребляемой памяти {old_mem_usage / new_mem_usage:.2f}')
# Out:
# Прежнее потребление памяти:  371349
# После конвертации  41232
# Улучшение в потребляемой памяти 9.01

# %%
date.dt.dayofweek.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: date, dtype: int64

# %%
date.dt.to_period('1M').head()
# Out:
# 0   2019-06
# 1   2019-06
# 2   2019-06
# 3   2019-06
# 4   2019-06
# Name: date, dtype: object

# %% [markdown]
# #### Уменьшение потребление RAM

# %%
mem_usage = df.memory_usage(deep=True).sort_values(ascending=False)
mem_usage.head()
# Out:
# location      419663
# Fight_type    389133
# date          371269
# Format        362276
# win_by        359734
# dtype: int64

# %% [markdown]
# ### Категории

# %%
for column_name in df.select_dtypes(include='object'):
    print(column_name, df[column_name].nunique())
# Out:
# R_fighter 1334
# B_fighter 1774
# R_SIG_STR. 3038
# B_SIG_STR. 2903
# R_SIG_STR_pct 95
# B_SIG_STR_pct 90
# R_TOTAL_STR. 3681
# B_TOTAL_STR. 3479
# R_TD 157
# B_TD 154
# R_TD_pct 69
# B_TD_pct 62
# R_HEAD 2620
# B_HEAD 2475
# R_BODY 541
# B_BODY 508
# R_LEG 393
# B_LEG 355
# R_DISTANCE 2382
# B_DISTANCE 2391
# R_CLINCH 472
# B_CLINCH 469
# R_GROUND 641
# B_GROUND 465
# win_by 10
# last_round_time 333
# Format 19
# Referee 190
# date 476
# location 157
# Fight_type 112
# Winner 1267

# %%
print(df['win_by'].unique().tolist())
categories = [
     'Не категория',
     'KO/TKO',
     "TKO - Doctor's Stoppage",
     'Decision - Unanimous',
     'Submission',
     'Decision - Split',
     'Decision - Majority',
     'DQ',
     'Overturned',
     'Could Not Continue',
     'Other',

]
# Out:
# ['KO/TKO', "TKO - Doctor's Stoppage", 'Decision - Unanimous', 'Submission', 'Decision - Split', 'Decision - Majority', 'DQ', 'Overturned', 'Could Not Continue', 'Other']

# %%
raw_cats = pd.Categorical(df['win_by'], categories=categories, ordered=True)
win_by = pd.Series(raw_cats)
win_by.head()
# Out:
# 0                     KO/TKO
# 1                     KO/TKO
# 2    TKO - Doctor's Stoppage
# 3       Decision - Unanimous
# 4       Decision - Unanimous
# dtype: category
# Categories (11, object): [Не категория < KO/TKO < TKO - Doctor's Stoppage < Decision - Unanimous ... DQ < Overturned < Could Not Continue < Other]

# %%
raw_cats = pd.Categorical(df['win_by'], categories=categories, ordered=False)
win_by = pd.Series(raw_cats)
win_by.head()
# Out:
# 0                     KO/TKO
# 1                     KO/TKO
# 2    TKO - Doctor's Stoppage
# 3       Decision - Unanimous
# 4       Decision - Unanimous
# dtype: category
# Categories (11, object): [Не категория, KO/TKO, TKO - Doctor's Stoppage, Decision - Unanimous, ..., DQ, Overturned, Could Not Continue, Other]

# %%
raw_cats = pd.Categorical(df['win_by'], categories=categories, ordered=True)
win_by = pd.Series(raw_cats)
win_by.head()
# Out:
# 0                     KO/TKO
# 1                     KO/TKO
# 2    TKO - Doctor's Stoppage
# 3       Decision - Unanimous
# 4       Decision - Unanimous
# dtype: category
# Categories (11, object): [Не категория < KO/TKO < TKO - Doctor's Stoppage < Decision - Unanimous ... DQ < Overturned < Could Not Continue < Other]

# %%
old_mem_usage = df['win_by'].memory_usage(deep='True')
new_mem_usage = win_by.memory_usage(deep='True')
print('Прежнее потребление памяти: ', old_mem_usage)
print('После конвертации ', new_mem_usage)
print(f'Улучшение в потребляемой памяти {old_mem_usage / new_mem_usage:.2f}')
# Out:
# Прежнее потребление памяти:  359814
# После конвертации  6373
# Улучшение в потребляемой памяти 56.46

# %% [markdown]
# ### Groupby

# %% [markdown]
# <center> <img src="groupby.jpeg" width=1800>

# %%
df.groupby('Winner').last_round

# %%
df.groupby('Winner').last_round.mean().head()
# Out:
# Winner
# Aaron Riley             3.000000
# Aaron Rosa              3.000000
# Aaron Simpson           2.571429
# Abdul Razak Alhassan    1.000000
# Abdul-Kerim Edilov      2.000000
# Name: last_round, dtype: float64

# %%
df.groupby('Winner').last_round.agg(['mean', 'std', 'size', lambda x: max(x)]).head()
# Out:
#                           mean       std  size  <lambda>
# Winner
# Aaron Riley           3.000000  0.000000     3         3
# Aaron Rosa            3.000000       NaN     1         3
# Aaron Simpson         2.571429  0.786796     7         3
# Abdul Razak Alhassan  1.000000  0.000000     4         1
# Abdul-Kerim Edilov    2.000000       NaN     1         2

# %% [markdown]
# ### Resample

# %% [markdown]
# <center> <img src="pandalast.jpeg" width=1800>

# %%
df = df.set_index(date)
df.head()
# Out:
#                        R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR.  \
# date
# 2019-06-08          Henry Cejudo   Marlon Moraes     0     0   90 of 171
# 2019-06-08  Valentina Shevchenko     Jessica Eye     1     0     8 of 11
# 2019-06-08         Tony Ferguson  Donald Cerrone     0     0  104 of 200
# 2019-06-08         Jimmie Rivera        Petr Yan     0     2   73 of 192
# 2019-06-08           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144
#
#            B_SIG_STR. R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  \
# date
# 2019-06-08  57 of 119           52%           47%    99 of 182    59 of 121
# 2019-06-08    2 of 12           72%           16%     37 of 40     42 of 52
# 2019-06-08  68 of 185           52%           36%   104 of 200    68 of 185
# 2019-06-08  56 of 189           38%           29%    76 of 195    58 of 192
# 2019-06-08  73 of 123           44%           59%    66 of 146    81 of 131
#
#                     ...          B_GROUND                   win_by last_round  \
# date                ...
# 2019-06-08          ...            1 of 1                   KO/TKO          3
# 2019-06-08          ...            0 of 0                   KO/TKO          2
# 2019-06-08          ...            0 of 0  TKO - Doctor's Stoppage          2
# 2019-06-08          ...           4 of 10     Decision - Unanimous          3
# 2019-06-08          ...            6 of 6     Decision - Unanimous          3
#
#            last_round_time             Format          Referee           date  \
# date
# 2019-06-08            4:51  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019
# 2019-06-08            0:26  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019
# 2019-06-08            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 2019-06-08            5:00      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019
# 2019-06-08            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
#
#                           location                        Fight_type  \
# date
# 2019-06-08  Chicago, Illinois, USA       UFC Bantamweight Title Bout
# 2019-06-08  Chicago, Illinois, USA  UFC Women's Flyweight Title Bout
# 2019-06-08  Chicago, Illinois, USA                  Lightweight Bout
# 2019-06-08  Chicago, Illinois, USA                 Bantamweight Bout
# 2019-06-08  Chicago, Illinois, USA                  Heavyweight Bout
#
#                           Winner
# date
# 2019-06-08          Henry Cejudo
# 2019-06-08  Valentina Shevchenko
# 2019-06-08         Tony Ferguson
# 2019-06-08              Petr Yan
# 2019-06-08         Blagoy Ivanov
#
# [5 rows x 41 columns]

# %%
df.resample('1M')['last_round'].mean().tail(5)
# Out:
# date
# 2019-02-28    2.183673
# 2019-03-31    2.451613
# 2019-04-30    2.540541
# 2019-05-31    2.567568
# 2019-06-30    2.520000
# Freq: M, Name: last_round, dtype: float64

# %% [markdown]
# ### Method Chaining

# %% [markdown]
# <center> <img src="redpanda.jpeg" width=1800>

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
df = df.set_index(date)
last_round_data = df.resample('1M')['last_round'].mean()
last_round_data = last_round_data.fillna(0)
filtered_last_round_data = last_round_data['2014-01-01':]
filtered_last_round_data.plot(figsize=(15, 9));

# %%
(
    df.set_index(date)
    .resample('1M')
    ['last_round'].mean()
    .fillna(0)
    .loc['2014-01-01':]
    .plot(figsize=(15, 9))
);

# %%
cities = df['location'].str.split(',').str[0]
df

# %%
df
# Out:
#                         R_fighter            B_fighter  R_KD  B_KD  \
# date
# 2019-06-08           Henry Cejudo        Marlon Moraes     0     0
# 2019-06-08   Valentina Shevchenko          Jessica Eye     1     0
# 2019-06-08          Tony Ferguson       Donald Cerrone     0     0
# 2019-06-08          Jimmie Rivera             Petr Yan     0     2
# 2019-06-08            Tai Tuivasa        Blagoy Ivanov     0     1
# 2019-06-08         Tatiana Suarez        Nina Ansaroff     0     0
# 2019-06-08      Aljamain Sterling         Pedro Munhoz     0     0
# 2019-06-08  Karolina Kowalkiewicz         Alexa Grasso     0     0
# 2019-06-08          Ricardo Lamas        Calvin Kattar     0     1
# 2019-06-08            Yan Xiaonan          Angela Hill     0     0
# 2019-06-08            Bevon Lewis       Darren Stewart     0     0
# 2019-06-08         Eddie Wineland       Grigorii Popov     2     0
# 2019-06-08      Katlyn Chookagian    Joanne Calderwood     0     0
# 2019-06-01   Alexander Gustafsson        Anthony Smith     0     0
# 2019-06-01            Jimi Manuwa     Aleksandar Rakic     0     1
# 2019-06-01       Makwan Amirkhani       Chris Fishgold     0     0
# 2019-06-01         Damir Hadzovic      Christos Giagos     0     0
# 2019-06-01          Daniel Teymur          Sung Bin Jo     0     0
# 2019-06-01           Rostem Akman    Sergey Khandozhko     0     1
# 2019-06-01          Tonya Evinger        Lina Lansberg     0     0
# 2019-06-01             Stevie Ray      Leonardo Santos     0     1
# 2019-06-01              Nick Hein        Frank Camacho     0     0
# 2019-06-01            Bea Malecki         Duda Santana     0     0
# 2019-06-01           Darko Stosic          Devin Clark     0     0
# 2019-06-01           Joel Alvarez     Danilo Belluardo     0     0
# 2019-05-18       Rafael Dos Anjos            Kevin Lee     0     0
# 2019-05-18  Antonio Carlos Junior         Ian Heinisch     0     0
# 2019-05-18         Megan Anderson      Felicia Spencer     0     0
# 2019-05-18          Vicente Luque       Derrick Krantz     1     0
# 2019-05-18       Charles Oliveira            Nik Lentz     1     0
# ...                           ...                  ...   ...   ...
# 1994-12-16             Guy Mezger          Jason Fairn     0     1
# 1994-09-09           Steve Jennum        Harold Howard     0     0
# 1994-09-09           Ken Shamrock   Felix Lee Mitchell     0     0
# 1994-09-09           Royce Gracie        Kimo Leopoldo     0     0
# 1994-09-09          Harold Howard         Roland Payne     1     0
# 1994-09-09           Ken Shamrock  Christophe Leninger     0     0
# 1994-09-09          Keith Hackney  Emmanuel Yarborough     1     0
# 1994-03-11           Royce Gracie        Patrick Smith     0     0
# 1994-03-11           Royce Gracie        Remco Pardoel     0     0
# 1994-03-11          Patrick Smith        Johnny Rhodes     0     0
# 1994-03-11           Royce Gracie        Jason DeLucia     0     0
# 1994-03-11          Remco Pardoel         Orlando Wiet     0     0
# 1994-03-11          Johnny Rhodes          Fred Ettish     1     0
# 1994-03-11          Patrick Smith         Scott Morris     0     0
# 1994-03-11           Royce Gracie      Minoki Ichihara     0     0
# 1994-03-11          Jason DeLucia          Scott Baker     0     0
# 1994-03-11          Remco Pardoel   Alberta Cerra Leon     0     0
# 1994-03-11           Orlando Wiet     Robert Lucarelli     0     0
# 1994-03-11          Frank Hamaker      Thaddeus Luster     0     0
# 1994-03-11          Johnny Rhodes        David Levicki     0     0
# 1994-03-11          Patrick Smith           Ray Wizard     0     0
# 1994-03-11           Scott Morris       Sean Daugherty     0     0
# 1993-11-12           Royce Gracie       Gerard Gordeau     0     0
# 1993-11-12          Jason DeLucia        Trent Jenkins     0     0
# 1993-11-12           Royce Gracie         Ken Shamrock     0     0
# 1993-11-12         Gerard Gordeau         Kevin Rosier     1     0
# 1993-11-12           Ken Shamrock        Patrick Smith     0     0
# 1993-11-12           Royce Gracie        Art Jimmerson     0     0
# 1993-11-12           Kevin Rosier         Zane Frazier     2     0
# 1993-11-12         Gerard Gordeau           Teila Tuli     0     0
#
#             R_SIG_STR.  B_SIG_STR. R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR.  \
# date
# 2019-06-08   90 of 171   57 of 119           52%           47%    99 of 182
# 2019-06-08     8 of 11     2 of 12           72%           16%     37 of 40
# 2019-06-08  104 of 200   68 of 185           52%           36%   104 of 200
# 2019-06-08   73 of 192   56 of 189           38%           29%    76 of 195
# 2019-06-08   64 of 144   73 of 123           44%           59%    66 of 146
# 2019-06-08   75 of 142    48 of 99           52%           48%    95 of 166
# 2019-06-08  174 of 349  105 of 265           49%           39%   175 of 350
# 2019-06-08   90 of 232  148 of 369           38%           40%    92 of 234
# 2019-06-08    12 of 29    22 of 41           41%           53%     12 of 29
# 2019-06-08   94 of 249   71 of 144           37%           49%   105 of 264
# 2019-06-08    31 of 84    30 of 73           36%           41%     45 of 98
# 2019-06-08   74 of 171   55 of 150           43%           36%    74 of 171
# 2019-06-08   82 of 221  112 of 266           37%           42%   108 of 250
# 2019-06-01   72 of 151   49 of 104           47%           47%    73 of 152
# 2019-06-01      2 of 3      2 of 7           66%           28%       2 of 3
# 2019-06-01     9 of 27    16 of 52           33%           30%     18 of 36
# 2019-06-01    24 of 61   47 of 113           39%           41%     42 of 87
# 2019-06-01    40 of 83    21 of 63           48%           33%     49 of 93
# 2019-06-01   39 of 100   60 of 149           39%           40%    40 of 103
# 2019-06-01     6 of 11    50 of 68           54%           73%     68 of 83
# 2019-06-01     2 of 11    12 of 16           18%           75%      2 of 11
# 2019-06-01    37 of 79  100 of 201           46%           49%     45 of 87
# 2019-06-01    19 of 71   42 of 106           26%           39%     30 of 82
# 2019-06-01    26 of 55    40 of 95           47%           42%     50 of 82
# 2019-06-01    19 of 41    13 of 20           46%           65%    87 of 113
# 2019-05-18   60 of 111    35 of 97           54%           36%    75 of 126
# 2019-05-18    15 of 33    39 of 67           45%           58%     25 of 43
# 2019-05-18      3 of 6    22 of 31           50%           70%       5 of 8
# 2019-05-18    18 of 25     6 of 18           72%           33%     18 of 25
# 2019-05-18    38 of 59    18 of 49           64%           36%     43 of 64
# ...                ...         ...           ...           ...          ...
# 1994-12-16    19 of 30     9 of 12           63%           75%     23 of 34
# 1994-09-09     6 of 11      2 of 6           54%           33%      7 of 13
# 1994-09-09      4 of 4      3 of 3          100%          100%       7 of 7
# 1994-09-09      2 of 6      6 of 9           33%           66%     17 of 21
# 1994-09-09     9 of 12      3 of 4           75%           75%     12 of 15
# 1994-09-09      8 of 9      1 of 2           88%           50%     16 of 20
# 1994-09-09    34 of 50      1 of 5           68%           20%     36 of 52
# 1994-03-11      4 of 4      1 of 2          100%           50%     11 of 11
# 1994-03-11      0 of 0      0 of 0            0%            0%       0 of 0
# 1994-03-11     5 of 12      4 of 9           41%           44%      5 of 12
# 1994-03-11      0 of 0      0 of 0            0%            0%       0 of 0
# 1994-03-11      7 of 7      1 of 2          100%           50%       7 of 7
# 1994-03-11    13 of 29      4 of 7           44%           57%     21 of 38
# 1994-03-11    13 of 17      0 of 0           76%            0%     19 of 25
# 1994-03-11      2 of 4      3 of 7           50%           42%   110 of 114
# 1994-03-11      3 of 5      0 of 2           60%            0%     20 of 25
# 1994-03-11      4 of 6      1 of 3           66%           33%     20 of 22
# 1994-03-11     8 of 12      2 of 6           66%           33%     11 of 15
# 1994-03-11      2 of 3      0 of 0           66%            0%     14 of 15
# 1994-03-11    11 of 17      4 of 5           64%           80%     74 of 86
# 1994-03-11      1 of 1      1 of 1          100%          100%       1 of 1
# 1994-03-11      1 of 1      0 of 4          100%            0%       2 of 2
# 1993-11-12      1 of 2      0 of 0           50%            0%       3 of 4
# 1993-11-12      3 of 9      1 of 7           33%           14%       3 of 9
# 1993-11-12      0 of 0      0 of 0            0%            0%     12 of 12
# 1993-11-12    11 of 17      0 of 3           64%            0%     11 of 17
# 1993-11-12      1 of 1      4 of 8          100%           50%       4 of 4
# 1993-11-12      0 of 3      0 of 0            0%            0%       4 of 7
# 1993-11-12    15 of 27    12 of 28           55%           42%     38 of 53
# 1993-11-12      3 of 5      0 of 1           60%            0%       3 of 5
#
#            B_TOTAL_STR.          ...           B_GROUND  \
# date                             ...
# 2019-06-08    59 of 121          ...             1 of 1
# 2019-06-08     42 of 52          ...             0 of 0
# 2019-06-08    68 of 185          ...             0 of 0
# 2019-06-08    58 of 192          ...            4 of 10
# 2019-06-08    81 of 131          ...             6 of 6
# 2019-06-08    54 of 105          ...             5 of 5
# 2019-06-08   108 of 269          ...             0 of 0
# 2019-06-08   163 of 384          ...             0 of 0
# 2019-06-08     22 of 41          ...             4 of 5
# 2019-06-08    78 of 151          ...             2 of 2
# 2019-06-08     40 of 84          ...             0 of 0
# 2019-06-08    55 of 150          ...             0 of 0
# 2019-06-08   141 of 300          ...             1 of 2
# 2019-06-01    51 of 107          ...             5 of 5
# 2019-06-01       2 of 7          ...             0 of 0
# 2019-06-01     16 of 52          ...             0 of 0
# 2019-06-01    67 of 141          ...            3 of 12
# 2019-06-01     23 of 65          ...             1 of 1
# 2019-06-01    60 of 151          ...             0 of 0
# 2019-06-01   151 of 181          ...           42 of 54
# 2019-06-01     12 of 16          ...             0 of 0
# 2019-06-01   105 of 208          ...             0 of 0
# 2019-06-01    48 of 112          ...             2 of 2
# 2019-06-01    90 of 149          ...             1 of 1
# 2019-06-01     56 of 68          ...             5 of 7
# 2019-05-18    40 of 102          ...             1 of 1
# 2019-05-18    79 of 115          ...           21 of 29
# 2019-05-18     25 of 34          ...           13 of 15
# 2019-05-18      9 of 23          ...             1 of 1
# 2019-05-18     21 of 53          ...             2 of 2
# ...                 ...          ...                ...
# 1994-12-16     12 of 15          ...             4 of 4
# 1994-09-09       3 of 7          ...             0 of 1
# 1994-09-09     21 of 22          ...             0 of 0
# 1994-09-09      6 of 10          ...             3 of 5
# 1994-09-09       3 of 4          ...             0 of 0
# 1994-09-09     21 of 23          ...             0 of 0
# 1994-09-09       4 of 9          ...             1 of 3
# 1994-03-11       2 of 3          ...             0 of 0
# 1994-03-11       0 of 0          ...             0 of 0
# 1994-03-11       4 of 9          ...             0 of 0
# 1994-03-11       0 of 0          ...             0 of 0
# 1994-03-11       5 of 7          ...             0 of 0
# 1994-03-11      7 of 11          ...             0 of 0
# 1994-03-11       0 of 0          ...             0 of 0
# 1994-03-11     12 of 16          ...             3 of 5
# 1994-03-11     14 of 23          ...             0 of 0
# 1994-03-11      9 of 11          ...             0 of 2
# 1994-03-11       2 of 6          ...             0 of 0
# 1994-03-11       0 of 0          ...             0 of 0
# 1994-03-11    95 of 102          ...             1 of 1
# 1994-03-11       2 of 2          ...             0 of 0
# 1994-03-11       1 of 5          ...             0 of 0
# 1993-11-12       0 of 0          ...             0 of 0
# 1993-11-12       1 of 7          ...             0 of 0
# 1993-11-12       0 of 0          ...             0 of 0
# 1993-11-12       0 of 3          ...             0 of 0
# 1993-11-12     16 of 20          ...             2 of 6
# 1993-11-12       0 of 0          ...             0 of 0
# 1993-11-12     13 of 29          ...             2 of 2
# 1993-11-12       0 of 1          ...             0 of 0
#
#                              win_by last_round last_round_time  \
# date
# 2019-06-08                   KO/TKO          3            4:51
# 2019-06-08                   KO/TKO          2            0:26
# 2019-06-08  TKO - Doctor's Stoppage          2            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08                   KO/TKO          1            4:06
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-08                   KO/TKO          2            4:47
# 2019-06-08     Decision - Unanimous          3            5:00
# 2019-06-01               Submission          4            2:38
# 2019-06-01                   KO/TKO          1            0:47
# 2019-06-01               Submission          2            4:25
# 2019-06-01     Decision - Unanimous          3            5:00
# 2019-06-01     Decision - Unanimous          3            5:00
# 2019-06-01     Decision - Unanimous          3            5:00
# 2019-06-01     Decision - Unanimous          3            5:00
# 2019-06-01                   KO/TKO          1            2:17
# 2019-06-01                   KO/TKO          2            4:56
# 2019-06-01               Submission          2            1:59
# 2019-06-01     Decision - Unanimous          3            5:00
# 2019-06-01                   KO/TKO          2            2:22
# 2019-05-18               Submission          4            3:47
# 2019-05-18     Decision - Unanimous          3            5:00
# 2019-05-18               Submission          1            3:24
# 2019-05-18                   KO/TKO          1            3:52
# 2019-05-18                   KO/TKO          2            2:11
# ...                             ...        ...             ...
# 1994-12-16                   KO/TKO          1            2:13
# 1994-09-09                   KO/TKO          1            1:27
# 1994-09-09               Submission          1            4:34
# 1994-09-09               Submission          1            4:40
# 1994-09-09                   KO/TKO          1            0:46
# 1994-09-09                   KO/TKO          1            4:49
# 1994-09-09                   KO/TKO          1            1:59
# 1994-03-11                   KO/TKO          1            1:17
# 1994-03-11               Submission          1            1:31
# 1994-03-11               Submission          1            1:07
# 1994-03-11               Submission          1            1:07
# 1994-03-11                   KO/TKO          1            1:29
# 1994-03-11               Submission          1            3:07
# 1994-03-11                   KO/TKO          1            0:30
# 1994-03-11               Submission          1            5:08
# 1994-03-11               Submission          1            6:41
# 1994-03-11               Submission          1            9:51
# 1994-03-11                   KO/TKO          1            2:50
# 1994-03-11               Submission          1            4:52
# 1994-03-11                   KO/TKO          1           12:13
# 1994-03-11               Submission          1            0:58
# 1994-03-11               Submission          1            0:20
# 1993-11-12               Submission          1            1:44
# 1993-11-12               Submission          1            0:52
# 1993-11-12               Submission          1            0:57
# 1993-11-12                   KO/TKO          1            0:59
# 1993-11-12               Submission          1            1:49
# 1993-11-12               Submission          1            2:18
# 1993-11-12                   KO/TKO          1            4:20
# 1993-11-12                   KO/TKO          1            0:26
#
#                        Format               Referee                date  \
# date
# 2019-06-08  5 Rnd (5-5-5-5-5)          Marc Goddard       June 08, 2019
# 2019-06-08  5 Rnd (5-5-5-5-5)       Robert Madrigal       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Dan Miragliotta       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Kevin MacDonald       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Dan Miragliotta       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Robert Madrigal       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)          Marc Goddard       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Kevin MacDonald       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Dan Miragliotta       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Robert Madrigal       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)          Marc Goddard       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Kevin MacDonald       June 08, 2019
# 2019-06-08      3 Rnd (5-5-5)       Dan Miragliotta       June 08, 2019
# 2019-06-01  5 Rnd (5-5-5-5-5)          Marc Goddard       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Kevin Sataki       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Marc Goddard       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)         Rich Mitchell       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)           Rebin Saber       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Leon Roberts       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Kevin Sataki       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Marc Goddard       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Leon Roberts       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)                   NaN       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)          Kevin Sataki       June 01, 2019
# 2019-06-01      3 Rnd (5-5-5)           Rebin Saber       June 01, 2019
# 2019-05-18  5 Rnd (5-5-5-5-5)       Dan Miragliotta        May 18, 2019
# 2019-05-18      3 Rnd (5-5-5)  Todd Ronald Anderson        May 18, 2019
# 2019-05-18      3 Rnd (5-5-5)        Keith Peterson        May 18, 2019
# 2019-05-18      3 Rnd (5-5-5)       Dan Miragliotta        May 18, 2019
# 2019-05-18      3 Rnd (5-5-5)  Todd Ronald Anderson        May 18, 2019
# ...                       ...                   ...                 ...
# 1994-12-16      No Time Limit         John McCarthy   December 16, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-09-09      No Time Limit         John McCarthy  September 09, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1994-03-11      No Time Limit         John McCarthy      March 11, 1994
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
# 1993-11-12      No Time Limit  Joao Alberto Barreto   November 12, 1993
#
#                                   location                        Fight_type  \
# date
# 2019-06-08          Chicago, Illinois, USA       UFC Bantamweight Title Bout
# 2019-06-08          Chicago, Illinois, USA  UFC Women's Flyweight Title Bout
# 2019-06-08          Chicago, Illinois, USA                  Lightweight Bout
# 2019-06-08          Chicago, Illinois, USA                 Bantamweight Bout
# 2019-06-08          Chicago, Illinois, USA                  Heavyweight Bout
# 2019-06-08          Chicago, Illinois, USA          Women's Strawweight Bout
# 2019-06-08          Chicago, Illinois, USA                 Bantamweight Bout
# 2019-06-08          Chicago, Illinois, USA          Women's Strawweight Bout
# 2019-06-08          Chicago, Illinois, USA                Featherweight Bout
# 2019-06-08          Chicago, Illinois, USA          Women's Strawweight Bout
# 2019-06-08          Chicago, Illinois, USA                 Middleweight Bout
# 2019-06-08          Chicago, Illinois, USA                 Bantamweight Bout
# 2019-06-08          Chicago, Illinois, USA            Women's Flyweight Bout
# 2019-06-01               Stockholm, Sweden            Light Heavyweight Bout
# 2019-06-01               Stockholm, Sweden            Light Heavyweight Bout
# 2019-06-01               Stockholm, Sweden                Featherweight Bout
# 2019-06-01               Stockholm, Sweden                  Lightweight Bout
# 2019-06-01               Stockholm, Sweden                Featherweight Bout
# 2019-06-01               Stockholm, Sweden                 Welterweight Bout
# 2019-06-01               Stockholm, Sweden         Women's Bantamweight Bout
# 2019-06-01               Stockholm, Sweden                  Lightweight Bout
# 2019-06-01               Stockholm, Sweden                  Lightweight Bout
# 2019-06-01               Stockholm, Sweden         Women's Bantamweight Bout
# 2019-06-01               Stockholm, Sweden            Light Heavyweight Bout
# 2019-06-01               Stockholm, Sweden                  Lightweight Bout
# 2019-05-18        Rochester, New York, USA                 Welterweight Bout
# 2019-05-18        Rochester, New York, USA                 Middleweight Bout
# 2019-05-18        Rochester, New York, USA        Women's Featherweight Bout
# 2019-05-18        Rochester, New York, USA                 Welterweight Bout
# 2019-05-18        Rochester, New York, USA                  Lightweight Bout
# ...                                    ...                               ...
# 1994-12-16            Tulsa, Oklahoma, USA                  Open Weight Bout
# 1994-09-09  Charlotte, North Carolina, USA       UFC 3 Tournament Title Bout
# 1994-09-09  Charlotte, North Carolina, USA                  Open Weight Bout
# 1994-09-09  Charlotte, North Carolina, USA                  Open Weight Bout
# 1994-09-09  Charlotte, North Carolina, USA                  Open Weight Bout
# 1994-09-09  Charlotte, North Carolina, USA                  Open Weight Bout
# 1994-09-09  Charlotte, North Carolina, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA       UFC 2 Tournament Title Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1994-03-11           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA       UFC 1 Tournament Title Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
# 1993-11-12           Denver, Colorado, USA                  Open Weight Bout
#
#                           Winner
# date
# 2019-06-08          Henry Cejudo
# 2019-06-08  Valentina Shevchenko
# 2019-06-08         Tony Ferguson
# 2019-06-08              Petr Yan
# 2019-06-08         Blagoy Ivanov
# 2019-06-08        Tatiana Suarez
# 2019-06-08     Aljamain Sterling
# 2019-06-08          Alexa Grasso
# 2019-06-08         Calvin Kattar
# 2019-06-08           Yan Xiaonan
# 2019-06-08        Darren Stewart
# 2019-06-08        Eddie Wineland
# 2019-06-08     Katlyn Chookagian
# 2019-06-01         Anthony Smith
# 2019-06-01      Aleksandar Rakic
# 2019-06-01      Makwan Amirkhani
# 2019-06-01       Christos Giagos
# 2019-06-01         Daniel Teymur
# 2019-06-01     Sergey Khandozhko
# 2019-06-01         Lina Lansberg
# 2019-06-01       Leonardo Santos
# 2019-06-01         Frank Camacho
# 2019-06-01           Bea Malecki
# 2019-06-01           Devin Clark
# 2019-06-01          Joel Alvarez
# 2019-05-18      Rafael Dos Anjos
# 2019-05-18          Ian Heinisch
# 2019-05-18       Felicia Spencer
# 2019-05-18         Vicente Luque
# 2019-05-18      Charles Oliveira
# ...                          ...
# 1994-12-16            Guy Mezger
# 1994-09-09          Steve Jennum
# 1994-09-09          Ken Shamrock
# 1994-09-09          Royce Gracie
# 1994-09-09         Harold Howard
# 1994-09-09          Ken Shamrock
# 1994-09-09         Keith Hackney
# 1994-03-11          Royce Gracie
# 1994-03-11          Royce Gracie
# 1994-03-11         Patrick Smith
# 1994-03-11          Royce Gracie
# 1994-03-11         Remco Pardoel
# 1994-03-11         Johnny Rhodes
# 1994-03-11         Patrick Smith
# 1994-03-11          Royce Gracie
# 1994-03-11         Jason DeLucia
# 1994-03-11         Remco Pardoel
# 1994-03-11          Orlando Wiet
# 1994-03-11         Frank Hamaker
# 1994-03-11         Johnny Rhodes
# 1994-03-11         Patrick Smith
# 1994-03-11          Scott Morris
# 1993-11-12          Royce Gracie
# 1993-11-12         Jason DeLucia
# 1993-11-12          Royce Gracie
# 1993-11-12        Gerard Gordeau
# 1993-11-12          Ken Shamrock
# 1993-11-12          Royce Gracie
# 1993-11-12          Kevin Rosier
# 1993-11-12        Gerard Gordeau
#
# [5144 rows x 41 columns]
